# %%
# !pip install PyPDF2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting PyPDF2
#   Obtaining dependency information for PyPDF2 from https://files.pythonhosted.org/packages/8e/5e/c86a5643653825d3c913719e788e41386bee415c2b87b4f955432f2de6b2/pypdf2-3.0.1-py3-none-any.whl.metadata
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ---------------------------------------- 0.0/232.6 kB ? eta -:--:--
#    -------------------------- ------------- 153.6/232.6 kB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 232.6/232.6 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
import PyPDF2
from PyPDF2 import PdfFileReader

# %%
PyPDF2.__version__
# Out:
# '3.0.1'

# %%
pdf = open(r"C:\Users\Kasir\OneDrive\Documents\file1pdf.pdf","rb")
pdf_reader = PyPDF2.PdfReader(pdf)

print("Number of pages:",len(pdf_reader.pages))

page = pdf_reader.pages[1]

print(page.extract_text())

pdf.close()
# Out:
# Number of pages: 35
#
#
#  Development  Plan for Greater Mumbai 2014‐2034
# Acknowledgements
# The Consultant  wishes to thank the following  individuals  from the Municipal  Corporation  of
# Greater Mumbai for their invaluable  support, insights and contributions  towards ‘Working  Paper 1
# – Preparation  of Base Map’ for the preparation  of the Development  Plan for Greater Mumbai
# 2014‐34.
#  Mr. Subodh Kumar, IAS, Municipal  Commissioner;
#  Mr. Rajeev Kuknoor, Chief Engineer Development  Plan;
#  Mr. Sudhir Ghate, Deputy Chief Engineer Development  Plan;
#  Mr. A.G. Marathe, Deputy Chief Engineer Development  Plan;
#  Mr. R. Balachandran,  Executive  Engineer and Town Planning Officer, Development  Plan.
#  Our gratitude  to the following  experts for their invaluable  insights and support:
# 
# Mr. V.K Phatak, Former Chief Town Planner (MMRDA);
#  Mr. A.N Kale, Former Chief Engineer, (DP);
#  Mr. A. S Jain Former Dy. Chief Engineer, (DP).
#  We wish to especially  thank MCGM officers, Mr. Jagdish Talreja, Mr. Dinesh Naik, Mr. Hiren
# Daftardar,  Ms. Anita Naik for their continual  support since the
#  beginning  of the project and their
# help towards familiarization  and data collection.  They have been instrumental  in helping to
# contact various MCGM departments  as well as in helping to establish contact with personnel  from
# other government  departments  and organizations.  Many thanks for the MCGM team, for
# deploying  personnel,  particularly  Mr. Prasad Gharat, on extensive  field visits that have helped in
# understanding  actual ground conditions.
#
# We apologize  if we have inadvertently  omitted anyone to whom acknowledgement  is due. We hope
# and anticipate  the work's usefulness  for the intended purpose.

# %%
import PyPDF2, urllib , nltk

from io import BytesIO

from nltk.tokenize import word_tokenize

from nltk.corpus import stopwords

# %%
#Reading the PDF

wFile = urllib.request.urlopen('http://www.udri.org/pdf/02%20working%20paper%201.pdf')

pdfreader = PyPDF2.PdfReader(BytesIO(wFile.read()))

# %%
#extracting page 2 of the docuemnt

pageObj = pdfreader.pages[2]

page2 = pageObj.extract_text()

#Cleaning the text

punctuations = ['(',')',';',':','[',']',',','...','.']

tokens = word_tokenize(page2)

stop_words = stopwords.words('english')

keywords = [word for word in tokens if not word in stop_words and not word in punctuations]

# %%
keywords
# Out:
# ['Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '2014‐2034',
#  'Table',
#  'Contents',
#  'The',
#  'Consultant',
#  'wishes',
#  'thank',
#  'following',
#  'individuals',
#  'Municipal',
#  'Corporation',
#  'Greater',
#  'Mumbai',
#  'invaluable',
#  'support',
#  'insights',
#  'contributions',
#  'towards',
#  '‘',
#  'Working',
#  'Paper',
#  '1',
#  '–',
#  'Preparation',
#  'Base',
#  'Map',
#  '’',
#  'preparation',
#  'Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '2014‐34',
#  '.............................................................................................................................',
#  '..............',
#  '3',
#  'Our',
#  'gratitude',
#  'following',
#  'experts',
#  'invaluable',
#  'insights',
#  'support',
#  '............................',
#  '3',
#  'We',
#  'wish',
#  'especially',
#  'thank',
#  'MCGM',
#  'officers',
#  'Mr.',
#  'Jagdish',
#  'Talreja',
#  'Mr.',
#  'Dinesh',
#  'Naik',
#  'Mr.',
#  'Hiren',
#  'Daftardar',
#  'Ms.',
#  'Anita',
#  'Naik',
#  'continual',
#  'support',
#  'since',
#  'beginning',
#  'project',
#  'help',
#  'towards',
#  'familiarization',
#  'data',
#  'collection',
#  'They',
#  'instrumental',
#  'helping',
#  'contact',
#  'various',
#  'MCGM',
#  'departments',
#  'well',
#  'helping',
#  'establish',
#  'contact',
#  'personnel',
#  'government',
#  'departments',
#  'organizations',
#  'Many',
#  'thanks',
#  'MCGM',
#  'team',
#  'deploying',
#  'personnel',
#  'particularly',
#  'Mr.',
#  'Prasad',
#  'Gharat',
#  'extensive',
#  'field',
#  'visits',
#  'helped',
#  'understanding',
#  'actual',
#  'ground',
#  'conditions',
#  '........................................................................................',
#  '3',
#  'BEST',
#  '...............................................................................................................................',
#  '.................',
#  '5',
#  'Brihanmumbai',
#  'Electric',
#  'Supply',
#  'Transport',
#  'Undertaking',
#  '..............................................................',
#  '5',
#  'CIDCO',
#  '...............................................................................................................................',
#  '..............',
#  '5',
#  'City',
#  'Industrial',
#  'Development',
#  'Corporation',
#  '...............................................................................',
#  '5',
#  'CTP',
#  '...............................................................................................................................',
#  '..................',
#  '5',
#  'Comprehensive',
#  'Transportation',
#  'Plan',
#  '...............................................................................................',
#  '5',
#  'DP',
#  '...............................................................................................................................',
#  '....................',
#  '5',
#  'Development',
#  'Plan',
#  '..........................................................................................................................',
#  '5',
#  'DPGM34',
#  '...............................................................................................................................',
#  '..........',
#  '5',
#  'Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '2034',
#  '.......................................................................................',
#  '5',
#  'DCR',
#  '...............................................................................................................................',
#  '..................',
#  '5',
#  'Development',
#  'Control',
#  'Regulations',
#  '...................................................................................................',
#  '5',
#  'DGPS',
#  '...........................................................................................................................',
#  '....................',
#  '5',
#  'Digital',
#  'Global',
#  'Positioning',
#  'System',
#  '...................................................................................................',
#  '5',
#  'DPGM',
#  '...............................................................................................................................',
#  '..............',
#  '5',
#  'Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '...........................................................................................',
#  '5',
#  'ELU',
#  '...............................................................................................................................',
#  '..................',
#  '5',
#  'Existing',
#  'Land',
#  'use',
#  '.............................................................................................................................',
#  '5',
#  'FSI',
#  '...............................................................................................................................',
#  '....................',
#  '5',
#  'Floor',
#  'Space',
#  'Index',
#  '............................................................................................................................',
#  '5',
#  'GIS',
#  '...............................................................................................................................',
#  '...................',
#  '5']

# %%
name_list = list()

check =  ['Mr.', 'Mrs.', 'Ms.']

for idx, token in enumerate(tokens):

    if token.startswith(tuple(check)) and idx < (len(tokens)-1):

        name = token + tokens[idx+1] + ' ' +  tokens[idx+2]

        name_list.append(name)
print(name_list)
# Out:
# ['Mr.Jagdish Talreja', 'Mr.Dinesh Naik', 'Mr.Hiren Daftardar', 'Ms.Anita Naik', 'Mr.Prasad Gharat']

# %%
wFile.close()

# %%
# !pip install python-docx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting python-docx
#   Obtaining dependency information for python-docx from https://files.pythonhosted.org/packages/3e/3d/330d9efbdb816d3f60bf2ad92f05e1708e4a1b9abe80461ac3444c83f749/python_docx-1.1.2-py3-none-any.whl.metadata
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from python-docx) (4.9.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\kasir\appdata\roaming\python\python311\site-packages (from python-docx) (4.12.2)
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ---------------------------------------- 0.0/244.3 kB ? eta -:--:--
#    ----- ---------------------------------- 30.7/244.3 kB 1.4 MB/s eta 0:00:01
#    --------- ----------------------------- 61.4/244.3 kB 825.8 kB/s eta 0:00:01
#    --------- ----------------------------- 61.4/244.3 kB 825.8 kB/s eta 0:00:01
#    ---------------------- --------------- 143.4/244.3 kB 950.9 kB/s eta 0:00:01
#    ---------------------- --------------- 143.4/244.3 kB 950.9 kB/s eta 0:00:01
#    ---------------------- --------------- 143.4/244.3 kB 950.9 kB/s eta 0:00:01
#    ----------------------- -------------- 153.6/244.3 kB 541.0 kB/s eta 0:00:01
#    ----------------------- -------------- 153.6/244.3 kB 541.0 kB/s eta 0:00:01
#    ------------------------------ ------- 194.6/244.3 kB 491.5 kB/s eta 0:00:01
#    ------------------------------ ------- 194.6/244.3 kB 491.5 kB/s eta 0:00:01
#    ------------------------------ ------- 194.6/244.3 kB 491.5 kB/s eta 0:00:01
#    ------------------------------ ------- 194.6/244.3 kB 491.5 kB/s eta 0:00:01
#    ------------------------------ ------- 194.6/244.3 kB 491.5 kB/s eta 0:00:01
#    -------------------------------------- 244.3/244.3 kB 365.7 kB/s eta 0:00:00
# Installing collected packages: python-docx
# Successfully installed python-docx-1.1.2

# %%
import docx

# %%
doc = open(r"C:\Users\Kasir\Downloads\Batch-3 AD Documentation.docx","rb")

document = docx.Document(doc)

# %%
docu=""

for para in document.paragraphs:

    docu += para.text

#to see the output call docu

print(docu)
# Out:
# “SYMPTOSCAN”-PREDICTIVE HEALTHCARE THROUGH MACHINE LEARNING ANALYSIS OF SYMPTOMS A project report submitted to MALLA REDDY UNIVERSITYin partial fulfillment of the requirements for the award of degree ofBACHELOR OF TECHNOLGYinCOMPUTER SCIENCE & ENGINEERING (AI & ML)Submitted byKASIREDDY RAKSHITHA	: 2211CS020149GORATI VAISHNAVI	: 2211CS020155GINNUR CHAITANYA	: 2211CS020176 KAGULA SANDEEP YADAV	: 2211CS020182GUNDAM VIJITHA	: 2211CS020190Under the Guidance ofDr.R.NagarajuDEPARTMENT OF COMPUTER SCIENCE&ENGINEERING(AI&ML)COLLEGE CERTIFICATEThis is to certify that this is the bonafide record of the application development entitled,“SYMPTOSCAN”-PREDICTIVE HEALTHCARE THROUGH MACHINE LEARNING ANALYSIS OF SYMPTOMS Submitted by KASIREDDY RAKSHITHA (2211CS020149),GORATI VAISHNAVI (2211CS020155), GINNUR CHAITANYA (2211CS020176),  KAGULA SANDEEP YADAV (2211CS020182), GUNDAM VIJITHA (2211CS020190).B.Tech II year II semester, Department of CSE (AI&ML) during the year 2023-24. The results embodied in the report have not been submitted to any other university or institute for the award of any degree or diploma.PROJECT GUIDE	Dr.R Nagaraju                                  HEAD OF THE DEPARTMENT	DR. THAYYABA KHATOON CSE(AI&ML)EXTERNAL EXAMINERACKNOWLEDGEMENTWe have been truly blessed to have a wonderful internal guide Prof.DR.R.Nagaraju,  Department of AIML, Mallareddy University for guiding us to explore the ramification of our work and we express our sincere gratitude towards him for leading us through the completion of Project.We would like to say our sincere thanks to Prof.Arivalagan, Incharge & Assistant Professor, Department of AIML, Malla Reddy University for providing seamless support and right suggestions are given in the development of the APP.We would like to say our sincere thanks to Dr. Thayyaba Khatoon ,Head of the Department CSE(AIML), MallaReddy University for providing seamless support and right suggestions are given in the development of the APP.We wish to express our sincere thanks to Vice Chancellor sir and The Management of MallaReddy University for providing excellent infrastructure and their visionary thoughts to prepare ourselves industry ready by focusing on new technologies.Finally, we would like to thank our family members and friends for their moral support and encouragement to achieve goals.KASIREDDY RAKSHITHA	: 2211CS020149GORATI VAISHNAVI	: 2211CS020155GINNUR CHAITANYA	: 2211CS020176 KAGULA SANDEEP YADAV : 2211CS020182 GUNDAM VIJITHA	: 2211CS020190ABSTRACTMachine learning has become an important part of our lives and everything involves technology .We need to understand what is happening with the health of the person and our own health.For this we are implementing machine learning methodology in health care information. We need to make it safe while using and implementing some sort of algorithms and make sure that the information is private. In this we understand the human disease patterns and using random forest and other machine learning models work and predict the actual procedure a person has to follow to get a good health and avoid the different health loss activities . In this random forest is the most accurate algorithm which works with this concept and we need to analyze the other useful information for performing machine learning. We implement TMS algorithm which gives the trust that the algorithm based on the truth maintenance system. Using certain machine learning algorithms, we can analyze medical data to identify patterns and markers that may indicate the presence of certain diseasesCONTENTSCHAPTER – 1 INTRODUCTION TO THE APPLICATIONIn today's fast-paced world, keeping track of our health can sometimes feel like an overwhelming task. With so many potential symptoms and diseases to consider, it's easy to feel lost or uncertain about what steps to take next. However, with SymptoScan, you can now take control of your health in a convenient and efficient way.SymptoScan is an innovative mobile application desi ...

# %%
for i in range(len(document.paragraphs)):
    print("The content of the paragraph "+ str(i)+" is ：" + document.paragraphs[i].text+"\n")
# Out:
# The content of the paragraph 0 is ：“SYMPTOSCAN”
#
# The content of the paragraph 1 is ：-PREDICTIVE HEALTHCARE THROUGH MACHINE LEARNING ANALYSIS OF SYMPTOMS
#
# The content of the paragraph 2 is ：
#
# The content of the paragraph 3 is ：
#
# The content of the paragraph 4 is ：A project report submitted to MALLA REDDY UNIVERSITY
#
# The content of the paragraph 5 is ：in partial fulfillment of the requirements for the award of degree of
#
# The content of the paragraph 6 is ：
#
# The content of the paragraph 7 is ：
#
# The content of the paragraph 8 is ：BACHELOR OF TECHNOLGY
#
# The content of the paragraph 9 is ：in
#
# The content of the paragraph 10 is ：COMPUTER SCIENCE & ENGINEERING (AI & ML)
#
# The content of the paragraph 11 is ：
#
# The content of the paragraph 12 is ：
#
# The content of the paragraph 13 is ：Submitted by
#
# The content of the paragraph 14 is ：
#
# The content of the paragraph 15 is ：
#
# The content of the paragraph 16 is ：KASIREDDY RAKSHITHA	: 2211CS020149
#
# The content of the paragraph 17 is ：GORATI VAISHNAVI	: 2211CS020155
#
# The content of the paragraph 18 is ：GINNUR CHAITANYA	: 2211CS020176 KAGULA SANDEEP YADAV	: 2211CS020182
#
# The content of the paragraph 19 is ：GUNDAM VIJITHA	: 2211CS020190
#
# The content of the paragraph 20 is ：
#
# The content of the paragraph 21 is ：
#
# The content of the paragraph 22 is ：
#
# The content of the paragraph 23 is ：
#
# The content of the paragraph 24 is ：
#
# The content of the paragraph 25 is ：
#
# The content of the paragraph 26 is ：Under the Guidance of
#
# The content of the paragraph 27 is ：
#
# The content of the paragraph 28 is ：Dr.R.Nagaraju
#
# The content of the paragraph 29 is ：
#
# The content of the paragraph 30 is ：DEPARTMENT OF COMPUTER SCIENCE&ENGINEERING(AI&ML)
#
# The content of the paragraph 31 is ：
#
# The content of the paragraph 32 is ：
#
# The content of the paragraph 33 is ：COLLEGE CERTIFICATE
#
# The content of the paragraph 34 is ：
#
# The content of the paragraph 35 is ：
#
# The content of the paragraph 36 is ：This is to certify that this is the bonafide record of the application development entitled,“SYMPTOSCAN”
#
# The content of the paragraph 37 is ：-PREDICTIVE HEALTHCARE THROUGH MACHINE LEARNING ANALYSIS OF SYMPTOMS
#
# The content of the paragraph 38 is ：Submitted by KASIREDDY RAKSHITHA (2211CS020149),GORATI VAISHNAVI (2211CS020155), GINNUR CHAITANYA (2211CS020176),  KAGULA SANDEEP YADAV (2211CS020182), GUNDAM VIJITHA (2211CS020190).B.Tech II year II semester, Department of CSE (AI&ML) during the year 2023-24. The results embodied in the report have not been submitted to any other university or institute for the award of any degree or diploma.
#
# The content of the paragraph 39 is ：
#
# The content of the paragraph 40 is ：
#
# The content of the paragraph 41 is ：
#
# The content of the paragraph 42 is ：
#
# The content of the paragraph 43 is ：PROJECT GUIDE
#
# The content of the paragraph 44 is ：Dr.R Nagaraju                                  HEAD OF THE DEPARTMENT
#
# The content of the paragraph 45 is ：	DR. THAYYABA KHATOON CSE(AI&ML)
#
# The content of the paragraph 46 is ：
#
# The content of the paragraph 47 is ：
#
# The content of the paragraph 48 is ：
#
# The content of the paragraph 49 is ：
#
# The content of the paragraph 50 is ：
#
# The content of the paragraph 51 is ：EXTERNAL EXAMINER
#
# The content of the paragraph 52 is ：ACKNOWLEDGEMENT
#
# The content of the paragraph 53 is ：
#
# The content of the paragraph 54 is ：We have been truly blessed to have a wonderful internal guide Prof.DR.R.Nagaraju,  Department of AIML, Mallareddy University for guiding us to explore the ramification of our work and we express our sincere gratitude towards him for leading us through the completion of Project.
#
# The content of the paragraph 55 is ：We would like to say our sincere thanks to Prof.Arivalagan, Incharge & Assistant Professor, Department of AIML, Malla Reddy University for providing seamless support and right suggestions are given in the development of the APP.
#
# The content of the paragraph 56 is ：We would like to say our sincere thanks to Dr. Thayyaba Khatoon ,Head of the Department CSE(AIML), MallaReddy University for providing seamless support and right suggestions are given in the development of the APP.
#
# The content of the paragraph 57 is ：We wish to express our sincere thanks to Vice Chancellor sir and The Management of MallaReddy University for providing excellent infrastructure and their visionary thoughts to prepare ourselves industry ready by focusing on new technologies.
#
# The content of the paragraph 58 is ：Finally, we would like to thank our family members and friends for their moral support and encouragement to achieve goals.
#
# The content of the paragraph 59 is ：
#
# The content of the paragraph 60 is ：KASIREDDY RAKSHITHA	: 2211CS020149
#
# The content of the paragraph 61 is ：GORATI VAISHNAVI	: 2211CS020155
#
# The content of the paragraph 62 is ：GINNUR CHAITANYA	: 2211CS020176 KAGULA SANDEEP YADAV : 2211CS020182 GUNDAM VIJITHA	: 2211CS020190
#
# The content of the paragraph 63 is ：
#
# The content of the paragraph 64 is ：ABSTRACT
#
# The content of the paragraph 65 is ：
#
# The content of the paragraph 66 is ：
#
# The content of the paragraph 67 is ：Machine learning has become an important part of our lives and everything involves technology .We need to understand what is happening with the health of the person and our own health.
#
# The content of the paragraph 68 is ：
#
# The content of the paragraph 69 is ：For this we are implementing machine learning methodology in health care information. We need to make it safe while using and implementing some sort of algorithms and make sure that the information is private.
#
# The content of the paragraph 70 is ：
#
# The content of the paragraph 71 is ：In this we understand the human disease patterns and using random forest and other machine learning models work and predict the actual procedure a person has to follow to get a good health and avoid the different health loss activities .
#
# The content of the paragraph 72 is ：
#
# The content of the paragraph 73 is ：In this random forest is the most accurate algorithm which works with this concept and we need to analyze the other useful information for performing machine learning.
#
# The content of the paragraph 74 is ：
#
# The content of the paragraph 75 is ：We implement TMS algorithm which gives the trust that the algorithm based on the truth maintenance system
#
# The content of the paragraph 76 is ：.
#
# The content of the paragraph 77 is ：Using certain machine learning algorithms, we can analyze medical data to identify patterns and markers that may indicate the presence of certain diseases
#
# The content of the paragraph 78 is ：
#
# The content of the paragraph 79 is ：CONTENTS
#
# The content of the paragraph 80 is ：
#
# The content of the paragraph 81 is ：
#
# The content of the paragraph 82 is ：
#
# The content of the paragraph 83 is ：CHAPTER – 1 INTRODUCTION TO THE APPLICATION
#
# The content of the paragraph 84 is ：
#
# The content of the paragraph 85 is ：In today's fast-paced world, keeping track of our health can sometimes feel like an overwhelming task. With so many potential symptoms and diseases to consider, it's easy to feel lost or uncertain about what steps to take next. However, with SymptoScan, you can now take control of your health in a convenient and efficient way.
#
# The content of the paragraph 86 is ：SymptoScan is an innovative mobile application designed to help users detect potential health issues based on their symptoms. Whether you're experiencing a mild headache, a persistent cough, or any other discomfort, SymptoScan is here to provide you with valuable insights and guidance.
#
# The content of the paragraph 87 is ：Using advanced algorithms and medical databases, SymptoScan analyzes the symptoms you input and cross-references them with a vast array of known diseases and conditions. This process allows the app to generate a list of potential illnesses that may be causing your symptoms, along with relevant information about each condition.
#
# The content of the paragraph 88 is ：SymptoScan is more than just a symptom analyzer; it's your personal health companion, providing you with the tools and information you need to stay informed, proactive, and empowered on your journey towards optimal health and wellness. Download SymptoScan today and take the first step towards a healthier tomorrow.
#
# The content of the paragraph 89 is ：
#
# The content of the paragraph 90 is ：SymptoScan goes beyond traditional symptom analysis to offer a comprehensive and user-centric approach to health management. Whether you're proactively monitoring your health or seeking guidance during times of illness, SymptoScan is your reliable companion every step of the way. Download SymptoScan today and experience the future of personalized health care at your fingertips.
#
# The content of the paragraph 91 is ：
#
# The content of the paragraph 92 is ：
#
# The content of the paragraph 93 is ：
#
# The content of the paragraph 94 is ：
#
# The content of the paragraph 95 is ：
#
# The content of the paragraph 96 is ：
#
# The content of the paragraph 97 is ：
#
# The content of the paragraph 98 is ：
#
# The content of the paragraph 99 is ：
#
# The content of the paragraph 100 is ：
#
# The content of the paragraph 101 is ：
#
# The content of the paragraph 102 is ：
#
# The content of the paragraph 103 is ：
#
# The content of the paragraph 104 is ：
#
# The content of the paragraph 105 is ：
#
# The content of the paragraph 106 is ：
#
# The content of the paragraph 107 is ：
#
# The content of the paragraph 108 is ：
#
# The content of the paragraph 109 is ：- SUMMARY OF THE APPLICATION
#
# The content of the paragraph 110 is ：
#
# The content of the paragraph 111 is ：
#
# The content of the paragraph 112 is ："SymptoScan" is a cutting-edge mobile application designed to assist users in identifying
#
# The content of the paragraph 113 is ：potential health issues based on reported symptoms. This innovative app employs advanced
#
# The content of the paragraph 114 is ：algorithms to analyze symptom patterns provided by users, offering potential disease
#
# The content of the paragraph 115 is ：suggestions or medical conditions to consider. By simply inputting symptoms, users can
#
# The content of the paragraph 116 is ：receive valuable insights into their health, enabling early detection and proactive
#
# The content of the paragraph 117 is ：management of illnesses. SymptoScan revolutionizes healthcare accessibility by providing
#
# The content of the paragraph 118 is ：a convenient and efficient tool for symptom-based disease detection, empowering
#
# The content of the paragraph 119 is ：individuals to take control of their well-being.
#
# The content of the paragraph 120 is ：
#
# The content of the paragraph 121 is ：
#
# The content of the paragraph 122 is ：SymptoScan is a revolutionary mobile application that utilizes state-of-the-art technology
#
# The content of the paragraph 123 is ：to analyze symptoms and suggest potential diseases or medical conditions. By inputting
#
# The content of the paragraph 124 is ：symptoms into the app, users can receive rapid assessments and Recommendations
#
# The content of the paragraph 125 is ：forfurther medical attention. This user-friendly tool empowers individuals to take
#
# The content of the paragraph 126 is ：proactive measures towards their health, facilitating early detection and intervention when
#
# The content of the paragraph 127 is ：necessary. With its advanced algorithms and intuitive interface, SymptoScan is
#
# The content of the paragraph 128 is ：transforming the way people approach healthcare, offering convenience, accuracy, and
#
# The content of the paragraph 129 is ：peace of mind at their fingertips.
#
# The content of the paragraph 130 is ：
#
# The content of the paragraph 131 is ：                                      SymptoScan is a breakthrough mobile application designed to streamline
#
# The content of the paragraph 132 is ： the process of detecting diseases based on reported symptoms. Utilizing cutting-edge
#
# The content of the paragraph 133 is ：algorithms and machine learning techniques, the app swiftly analyzes user-input symptoms
#
# The content of the paragraph 134 is ：to provide insightful suggestions regarding potential health conditions. By offering prompt
#
# The content of the paragraph 135 is ：assessments and recommendations, SymptoScan enables users to promptly seek
#
# The content of the paragraph 136 is ：appropriate medical attention, leading to early intervention and improved health outcomes.
#
# The content of the paragraph 137 is ：With its intuitive interface and accessibility, SymptoScan revolutionizes the healthcare
#
# The content of the paragraph 138 is ：landscape, empowering individuals to proactively manage their well-being and make
#
# The content of the paragraph 139 is ：informed decisions about their health.
#
# The content of the paragraph 140 is ：
#
# The content of the paragraph 141 is ：
#
# The content of the paragraph 142 is ：
#
# The content of the paragraph 143 is ：
#
# The content of the paragraph 144 is ：
#
# The content of the paragraph 145 is ：
#
# The content of the paragraph 146 is ：
#
# The content of the paragraph 147 is ：
#
# The content of the paragraph 148 is ：
#
# The content of the paragraph 149 is ：
#
# The content of the paragraph 150 is ：1.2- BACKGROUND OF THE APPLICATION
#
# The content of the paragraph 151 is ：
#
# The content of the paragraph 152 is ：SymptoScan is an innovative mobile application designed to assist users in identifying potential health issues based on reported symptoms. The app utilizes advanced algorithms and medical databases to analyze symptoms inputted by the user and provide potential disease matches or suggestions for further medical attention. Here's a breakdown of its background and functionality:
#
# The content of the paragraph 153 is ：Development: SymptoScan was developed by a team of medical professionals, software engineers, and data scientists. The idea stemmed from the need to leverage technology to facilitate early detection of diseases and prompt medical intervention.
#
# The content of the paragraph 154 is ：
#
# The content of the paragraph 155 is ：Algorithm: The core of SymptoScan lies in its robust algorithm, which processes symptoms inputted by users and matches them against a comprehensive database of diseases, disorders, and medical conditions. The algorithm takes into account various factors such as the severity of symptoms, their duration, and any accompanying factors (like demographic information or medical history if provided).
#
# The content of the paragraph 156 is ：
#
# The content of the paragraph 157 is ：Database: SymptoScan draws from a vast repository of medical knowledge, including symptom profiles of diseases, diagnostic criteria, and treatment guidelines. This database is continuously updated to reflect the latest advancements in medical science and healthcare practices.
#
# The content of the paragraph 158 is ：
#
# The content of the paragraph 159 is ：User Interface: The app features an intuitive and user-friendly interface, allowing individuals to input their symptoms through simple text-based entry or, in some cases, by selecting from predefined lists. The interface may also prompt users with additional questions to gather more specific information about their symptoms.
#
# The content of the paragraph 160 is ：
#
# The content of the paragraph 161 is ：Output: After analyzing the symptoms, SymptoScan generates a list of potential diseases or health conditions that could be associated with the reported symptoms. It also provides relevant information about each suggested condition, including common symptoms, risk factors, and recommended next steps.
#
# The content of the paragraph 162 is ：
#
# The content of the paragraph 163 is ：Privacy and Security: Given the sensitive nature of health data, SymptoScan prioritizes user privacy and complies with stringent data protection regulations. It employs robust encryption protocols and anonymization techniques to safeguard user information.
#
# The content of the paragraph 164 is ：
#
# The content of the paragraph 165 is ：Integration: SymptoScan may offer integration with healthcare providers or telemedicine services, allowing users to seamlessly transition from symptom assessment to seeking medical advice or scheduling appointments with healthcare professionals.
#
# The content of the paragraph 166 is ：
#
# The content of the paragraph 167 is ：Feedback and Improvement: The app continuously collects feedback from users and healthcare professionals to enhance its accuracy and usability. User-reported outcomes and diagnostic accuracy help refine the algorithm and improve the app's performance over time.
#
# The content of the paragraph 168 is ：
#
# The content of the paragraph 169 is ：MODULES
#
# The content of the paragraph 170 is ：
#
# The content of the paragraph 171 is ：User Interface (UI):
#
# The content of the paragraph 172 is ：Functionality: Provides a user-friendly web-based interface for administrators and users, ensuring seamless access via a mobile app for on-the-go transactions.
#
# The content of the paragraph 173 is ：Purpose: Enhances user experience through an intuitive layout and navigation, promoting accessibility and ease of use.
#
# The content of the paragraph 174 is ：User Management:
#
# The content of the paragraph 175 is ：Functionality: Admin, staff, and user profiles with varying levels of access. Facilitates user registration and authentication processes.
#
# The content of the paragraph 176 is ：Purpose: Enables secure and controlled access to the application, allowing administrators to manage user roles effectively.
#
# The content of the paragraph 177 is ：Feedback and Adaptation:
#
# The content of the paragraph 178 is ：Functionality: Encourages regular user feedback for continuous application refinement.
#
# The content of the paragraph 179 is ：Purpose:	Facilitates	responsiveness	to	user	preferences,	fostering	ongoing improvements and adaptability.
#
# The content of the paragraph 180 is ：Search Functionality:
#
# The content of the paragraph 181 is ：Functionality: Implements user-friendly search features for efficient navigation and information retrieval.
#
# The content of the paragraph 182 is ：Purpose: Enhances the overall usability of the application by enabling users to quickly locate relevant information.
#
# The content of the paragraph 183 is ：Sign Up:
#
# The content of the paragraph 184 is ：Functionality: Allows users to create accounts by providing necessary details for registration.
#
# The content of the paragraph 185 is ：Purpose: Facilitates the registration process, ensuring a confirmed account for users to access and utilize application features.
#
# The content of the paragraph 186 is ：Login:
#
# The content of the paragraph 187 is ：Functionality: Enables users to sign in to the system, providing access to the application's functionalities.
#
# The content of the paragraph 188 is ：Purpose: Secures user-specific data and preferences, ensuring a personalized experience upon login.
#
# The content of the paragraph 189 is ：Forgot Password:
#
# The content of the paragraph 190 is ：Functionality: Offers a password recovery mechanism through security questions or OTP for users who forget their passwords.
#
# The content of the paragraph 191 is ：Purpose: Enhances user convenience and security by providing a reliable method for password retrieval.
#
# The content of the paragraph 192 is ：Security and Access Control:
#
# The content of the paragraph 193 is ：Functionality: Ensures data privacy and security through role-based access control.
#
# The content of the paragraph 194 is ：Purpose: Safeguards sensitive information and restricts unauthorized access, maintaining the confidentiality of user data.
#
# The content of the paragraph 195 is ：CHAPTER – 2 REQUIREMENTS OF THE APPLICATION
#
# The content of the paragraph 196 is ：
#
# The content of the paragraph 197 is ：Functional Requirements:
#
# The content of the paragraph 198 is ：User Authentication:
#
# The content of the paragraph 199 is ：Users must log in with a unique username and password after completing the registration process.
#
# The content of the paragraph 200 is ：Invalid login attempts should prevent access, ensuring security.
#
# The content of the paragraph 201 is ：Symptom Input:
#
# The content of the paragraph 202 is ：
#
# The content of the paragraph 203 is ：Users should be able to input their symptoms through various mediums such as text input, voice recognition, or selecting from a predefined list.
#
# The content of the paragraph 204 is ：The system should allow users to input multiple symptoms accurately.
#
# The content of the paragraph 205 is ：Symptom Analysis:
#
# The content of the paragraph 206 is ：The app should analyze the symptoms provided by the user to generate possible disease matches.
#
# The content of the paragraph 207 is ：Utilize algorithms or AI models to process symptoms and identify potential diseases.
#
# The content of the paragraph 208 is ：Disease Database:
#
# The content of the paragraph 209 is ：Maintain a comprehensive database of diseases, including symptoms, causes, treatments, and other relevant information.
#
# The content of the paragraph 210 is ：Regularly update the database to include new diseases or symptoms.
#
# The content of the paragraph 211 is ：Disease Matching:
#
# The content of the paragraph 212 is ：Based on the symptoms provided, the app should match them with diseases from the database.
#
# The content of the paragraph 213 is ：Prioritize diseases based on symptom severity, prevalence, and other factors.
#
# The content of the paragraph 214 is ：Accuracy and Reliability:
#
# The content of the paragraph 215 is ：Ensure that the matching algorithm provides accurate and reliable results.
#
# The content of the paragraph 216 is ：Implement measures to minimize false positives and false negatives.
#
# The content of the paragraph 217 is ：
#
# The content of the paragraph 218 is ：Non-Functional Requirements:
#
# The content of the paragraph 219 is ：User Interface (UI):
#
# The content of the paragraph 220 is ：The main screen should feature a simple and elegant UI to facilitate easy navigation for users, especially during registration and login.
#
# The content of the paragraph 221 is ：A visually appealing and user-friendly design is crucial for the overall user experience.
#
# The content of the paragraph 222 is ：User-Friendly Dialogs:
#
# The content of the paragraph 223 is ：User-friendly dialogs should be displayed to convey essential information about the application.
#
# The content of the paragraph 224 is ：Clear and understandable messages enhance user comprehension.
#
# The content of the paragraph 225 is ：Efficient User Interaction:
#
# The content of the paragraph 226 is ：The application should support efficient user interactions, allowing users to complete tasks with ease.
#
# The content of the paragraph 227 is ：Streamlined processes contribute to a positive and productive user experience.
#
# The content of the paragraph 228 is ：Reliable System Environment:
#
# The content of the paragraph 229 is ：The system must provide a reliable and stable environment for users to describe about their symptoms.
#
# The content of the paragraph 230 is ：Dependability ensures user confidence in the application's performance.
#
# The content of the paragraph 231 is ：User-Friendly Design:
#
# The content of the paragraph 232 is ：The application is designed with a user-friendly interface, promoting ease of use and accessibility.
#
# The content of the paragraph 233 is ：User-centric design principles enhance overall satisfaction.
#
# The content of the paragraph 234 is ：Technology Stack:
#
# The content of the paragraph 235 is ：Implementation involves HTML, CSS, and JavaScript for the front end, with MySQL serving as the backend for database connectivity.
#
# The content of the paragraph 236 is ：Responsive web design ensures compatibility with various screen sizes and devices.
#
# The content of the paragraph 237 is ：Security Measures:
#
# The content of the paragraph 238 is ：Robust security measures, including access control mechanisms, are in place to prevent unauthorized access to the application's panel and database.
#
# The content of the paragraph 239 is ：Unauthorized individuals are barred from accessing sensitive information.
#
# The content of the paragraph 240 is ：
#
# The content of the paragraph 241 is ：
#
# The content of the paragraph 242 is ：
#
# The content of the paragraph 243 is ：
#
# The content of the paragraph 244 is ：
#
# The content of the paragraph 245 is ：
#
# The content of the paragraph 246 is ：
#
# The content of the paragraph 247 is ：
#
# The content of the paragraph 248 is ：
#
# The content of the paragraph 249 is ：- SOFTWARE REQUIREMENTS
#
# The content of the paragraph 250 is ：
#
# The content of the paragraph 251 is ：
#
# The content of the paragraph 252 is ：Front End: HTML, JavaScript, CSS
#
# The content of the paragraph 253 is ：Back End: MySQL 8.1
#
# The content of the paragraph 254 is ：
#
# The content of the paragraph 255 is ：- HARDWARE REQUIREMENTS
#
# The content of the paragraph 256 is ：
#
# The content of the paragraph 257 is ：
#
# The content of the paragraph 258 is ：Operating Systems: Windows or Linux
#
# The content of the paragraph 259 is ：Processor: Intel Pentium IV or higher
#
# The content of the paragraph 260 is ：RAM: Atleast 2GB
#
# The content of the paragraph 261 is ：Disk Space: 250MB
#
# The content of the paragraph 262 is ：Device: Personal computer or laptop
#
# The content of the paragraph 263 is ：CHAPTER – 3
#
# The content of the paragraph 264 is ：DESIGN-ALGORITHM OR FLOWCHART
#
# The content of the paragraph 265 is ：
#
# The content of the paragraph 266 is ：ER Diagram:
#
# The content of the paragraph 267 is ：
#
# The content of the paragraph 268 is ：
#
# The content of the paragraph 269 is ：
#
# The content of the paragraph 270 is ：
#
# The content of the paragraph 271 is ：
#
# The content of the paragraph 272 is ：3.1 - SCREENSHOTS OF THE APP
#
# The content of the paragraph 273 is ：
#
# The content of the paragraph 274 is ：
#
# The content of the paragraph 275 is ：Fig.3.1 1- Home page
#
# The content of the paragraph 276 is ：
#
# The content of the paragraph 277 is ：
#
# The content of the paragraph 278 is ：
#
# The content of the paragraph 279 is ：
#
# The content of the paragraph 280 is ：
#
# The content of the paragraph 281 is ：Fig.3.1 2 login page
#
# The content of the paragraph 282 is ：
#
# The content of the paragraph 283 is ：
#
# The content of the paragraph 284 is ：
#
# The content of the paragraph 285 is ：
#
# The content of the paragraph 286 is ：
#
# The content of the paragraph 287 is ：
#
# The content of the paragraph 288 is ：
#
# The content of the paragraph 289 is ：
#
# The content of the paragraph 290 is ：
#
# The content of the paragraph 291 is ：
#
# The content of the paragraph 292 is ：
#
# The content of the paragraph 293 is ：
#
# The content of the paragraph 294 is ：

# %%
# !pip install bs4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting bs4
#   Obtaining dependency information for bs4 from https://files.pythonhosted.org/packages/51/bb/bf7aab772a159614954d84aa832c129624ba6c32faa559dfb200a534e50b/bs4-0.0.2-py2.py3-none-any.whl.metadata
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (from bs4) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.4)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
import urllib.request as urllib2

from bs4 import BeautifulSoup

# %%
response = urllib2.urlopen('https://en.wikipedia.org/wiki/Natural_language_processing')

html_doc = response.read()

# %%
#Parsing

soup = BeautifulSoup(html_doc, 'html.parser')

# Formating the parsed html file

strhtm = soup.prettify()

# Print few lines

print (strhtm[:5000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Natural language processing - Wikipedia
#   </title>
#   <script>
#    (function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available";var cookie=document.cookie.match(/(?:^|; )enwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split('%2C').forEach(function(pref){className=className.replace(new RegExp('(^| )'+pref.replace(/-clientpref-\w+$|[^\w-]+/g,'')+'-clientpref-\\w+( |$)'),'$1'+pref+'$2');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy",
# "wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"bb8cccbb-931f-4281-aaf8-3aff8c9effb8","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Natural_language_processing","wgTitle":"Natural language processing","wgCurRevisionId":1274942014,"wgRevisionId":1274942014,"wgArticleId":21652,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["All accuracy disputes","Accuracy disputes from December 2013","Harv and Sfn no-target errors","CS1 errors: periodical ignored","CS1 maint: location","Articles with short description","Short description is different from Wikidata","Articles needing additional references from May 2024","All articles needing additional references","All articles with unsourced statements","Articles with unsourced statements from May 2024","Commons category link from Wikidata",
# "Natural language processing","Computational fields of study","Computational linguistics","Speech recognition"],"wgPageViewLanguage":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Natural_language_processing","wgRelevantArticleId":21652,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgNoticeProject":"wikipedia","wgCiteReferencePreviewsActive":false,"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":0,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":60000,"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":false,"wgVector2022LanguageInHeader":true,
# "wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q30642","wgCheckUserClientHintsHeadersJsApi":["brands","architecture","bitness","fullVersionList","mobile","model","platform","platformVersion"],"GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,"wgGELevelingUpEnabledForUser":false};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","ext.math.styles":"ready","skins.vector.search.codex.styles":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","jquery.makeCollapsible.styles":"ready","ext.wikimediamessages.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","ext.scribunto.logs","site",
# "mediawiki.page.ready","jquery.makeCollapsible","mediawiki.toc","skins.vector.js","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips","ext.gadget.switcher","ext.urlShortener.toolbar","ext.centralauth.centralautologin","mmv.bootstrap","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visu
